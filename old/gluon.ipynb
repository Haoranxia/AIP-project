# %%
# !python mscoco.py --donwload-dir ./
# Out:
# python: can't open file 'c:\School\DELFT\AIP\AIP-project\mscoco.py': [Errno 2] No such file or directory

# %%
from gluoncv import data, utils
from matplotlib import pyplot as plt

data_dir = "./data/train2014"
annotations_dir = "./data/annotations/instances_train2014"
train_dataset = data.COCODetection(splits=[annotations_dir])
print('Num of training images:', len(train_dataset))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15492/3131489667.py in <module>
#       4 data_dir = "./data/train2014"
#       5 annotations_dir = "./data/annotations/instances_train2014"
# ----> 6 train_dataset = data.COCODetection(splits=[annotations_dir])
#       7 print('Num of training images:', len(train_dataset))
#
# c:\Users\haora\AppData\Local\Programs\Python\Python39\lib\site-packages\gluoncv\data\mscoco\detection.py in __init__(self, root, splits, transform, min_object_area, skip_empty, use_crowd)
#      62                  splits=('instances_val2017',), transform=None, min_object_area=0,
#      63                  skip_empty=True, use_crowd=True):
# ---> 64         super(COCODetection, self).__init__(root)
#      65         self._root = os.path.expanduser(root)
#      66         self._transform = transform
#
# ...
